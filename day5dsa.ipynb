# %%
def func(value,values):
    Var =1
    values[0]=44
t=3
v=[1,2,3]
func(t,v)
print(t,v[0])
# Out:
# 3 44

# %%
def f(i,values=[]):
    values.append(i)
    print(values)
f(1)
f(2)
f(3)
# Out:
# [1]
# [1, 2]
# [1, 2, 3]

# %%
#queue operations
import sys
class Queue:
    def __init__(self,size):
        self.myQueue= []       #creating queue
        self.queueSize= size  #size define

    def isFull(self):
            if len(self.myQueue)== size:
                return True
            else:
                return False

    def enQueue(self,value):
            if self.isFull():
                print("queue is full")
            else:
                self.myQueue.append(value)
       
    def display(self):
            print(self.myQueue)

    def isEmpty(self):
            if self.myQueue==[]:
                return True
            else:
                return False

    def deQueue(self):
        if self.isEmpty():
            print("Queue is empty")
        else:
            self.myQueue.pop(0)

    def peek(self):
            if self.isEmpty():
                print("queue is empty")
            else:
                print(self.myQueue[0])

    def delete(self):
            self.myQueue = None
                
size= int(input("enter size"))
obj = Queue(size)
print("stack has created")
while True:
    print("1. enqueue operation")
    print("2. display queue ")
    print("3. dequeue operation")
    print("4. peek operation")
    print("5. delete queue")
    print("6. exit")
    choice = int(input("enter your choice"))
    if choice == 1:
        value=int(input("enter element to add"))
        obj.enQueue(value)
    elif choice == 2:
        obj.display()
    elif choice==3:
        obj.deQueue()
    elif choice==4:
        obj.peek()
    elif choice==5:
        obj.delete()
    else:
        sys.exit()
# Out:
# enter size 5
# stack has created
# 1. enqueue operation
# 2. display queue
# 3. dequeue operation
# 4. peek operation
# 5. delete queue
# 6. exit

# %%
#mcq
fruit ={}
def addone(index):
    if index in fruit:
        fruit[index] +=1
    else:
        fruit[index] = 1
addone('Apple')
addone('Banana')
addone('apple')
print(len(fruit))
# Out:
# 3

# %%
n=int(input("number of students"))
d={}
for i in range(n):
    name=input("enter name")
    marks=int(input("enter marks"))
    d[name]=marks  #add key value
while True:
    name=input("enter name of student uh wnt to know marks")
    marks=d.get(name,-1)
    if marks== -1:
        print("student not found")
    else:
        print("marks of",name,"are",marks)
    option=input("do uh want to find another student marks[yes/no]")
    if option=="no":
        break
print("thanks for using our application")
# Out:
# number of students 3
# enter name raina
# enter marks 39
# enter name shail
# enter marks 67
# enter name ikk
# enter marks 90
# enter name of student uh wnt to know marks ikk
# marks of ikk are 90
# do uh want to find another student marks[yes/no] yes
# enter name of student uh wnt to know marks raina
# marks of raina are 39
# do uh want to find another student marks[yes/no] no
# thanks for using our application

# %%
#problem forwrd backwrd 
sen="learning python is very easy"
n=len(sen)
i=0
while i<n:
    print(sen[i])
    i+=1
print("backward")
i=-1
while i>=-n:
    print(sen[i])
    i-=1
# Out:
# l
# e
# a
# r
# n
# i
# n
# g
#
# p
# y
# t
# h
# o
# n
#
# i
# s
#
# v
# e
# r
# y
#
# e
# a
# s
# y
# backward
# y
# s
# a
# e
#
# y
# r
# e
# v
#
# s
# i
#
# n
# o
# h
# t
# y
# p
#
# g
# n
# i
# n
# r
# a
# e
# l

# %%
send="abcdfjgerj abcdfjger"
l=[]
l=send.split(" ")
a = l[0]
b = l[1]
for ch in a:
    if ch not in b:
        print(ch)

# %%
#vowel
v=['a','e','i','o','u']
w=input("enter word")
found=[]
for i in w:
    if i in v:
        if i not in found:
            found.append(i)
print("found vowel",found)
print('unique',len(found),'from given word',w)
# Out:
# enter word prashantjha
# found vowel ['a']
# unique 1 from given word prashantjha

# %%
x,y,z = map(int, input().split())
mylist = []
for i in range(x):
    a=int(input())
    mylist.append(a)

for j in mylist:
    if j>=y and j<=z:
        print(j,end=' ')
# Out:
#  6 30 50
#  29
#  38
#  12
#  48
#  39
#  55
# 38 48 39

# %%
import datetime
date=datetime.datetime.now()
print("its now:{:%d/%m/%Y %H:%M:%S}".format(date))
# Out:
# its now:16/05/2026 14:49:28

# %%
#mcq
x=["a","b","c"]
y=["a","b","c"]
z=[1,2,3]
print(x==y)
print(x==z)
print(x!=z)
# Out:
# True
# False
# True

# %%
v=[2**i for i in range(1,6)]
print(v)
# Out:
# [2, 4, 8, 16, 32]

# %%
sq={x:x*x for x in range(1,6)}
sq
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %%
doubles={x:2*x for x in range(1,6)}
print(doubles)
# Out:
# {1: 2, 2: 4, 3: 6, 4: 8, 5: 10}

# %%
a,b = [int(x) for x in input("enter 2 numbers").split()]
print("product",a*b)
# Out:
# enter 2 numbers 4 5
# product 20

# %%
a,b,c = [float(x) for x in input("enter 3 numbers").split(',')]
print("sum",a+b+c)
# Out:
# enter 3 numbers 3,4,5
# sum 12.0

# %%
my=[10,20,800,60,70]
for item in my:
    if item>400:
        print("this is not in my budget")
        continue
    print(item)
else:
    print("you have purchased everything")
# Out:
# 10
# 20
# this is not in my budget
# 60
# 70
# you have purchased everything

# %%
while True:
    username=input("enter username")
    password=input("enter password")
    if username=="admin" and password=="admin":
        print("login successful")
        break
    else:
        print("reenter ,details are not correct")
# Out:
# enter username admin
# enter password admin
# login successful

# %%
#tower of hanoi
import time
class Tower:
    def __init__(self):
        print("tower of hanoi game")
        print()
        print("given problem a=[3,2,1], b[], c[]")
        print()
        print("expected output a=[] b[] c[3,2,1]")
        self.a= []
        self.b= []
        self.c= []

    def tower(self,item):
        self.a.append(item)
        time.sleep(3)
        print("a=",self.a)
        print("items in tower a\n")

    def pass1(self):
        self.temp = self.a.pop(2)
        self.c.append(self.temp)
        time.sleep(3)
        print("a=", self.a  ," ", "b=",self.b  ," ","c=",self.c)
        print("pass one completed\n")

    def pass2(self):
        self.temp = self.a.pop(1)
        self.b.append(self.temp)
        time.sleep(3)
        print("a=", self.a  ," ", "b=",self.b  ," ","c=",self.c)
        print("pass one completed\n")
     
    def pass3(self):
        self.temp = self.c.pop(0)
        self.b.append(self.temp)
        time.sleep(3)
        print("a=", self.a  ," ", "b=",self.b  ," ","c=",self.c)
        print("pass one completed\n")

    def pass4(self):
        self.temp = self.a.pop(0)
        self.c.append(self.temp)
        time.sleep(3)
        print("a=", self.a  ," ", "b=",self.b  ," ","c=",self.c)
        print("pass one completed\n")

    def pass5(self):
        self.temp = self.b.pop(1)
        self.a.append(self.temp)
        time.sleep(3)
        print("a=", self.a  ," ", "b=",self.b  ," ","c=",self.c)
        print("pass one completed\n")

    def pass6(self):
        self.temp = self.b.pop(0)
        self.c.append(self.temp)
        time.sleep(3)
        print("a=", self.a  ," ", "b=",self.b  ," ","c=",self.c)
        print("pass one completed\n")
     
    def pass7(self):
        self.temp = self.a.pop(0)
        self.c.append(self.temp)
        time.sleep(3)
        print("a=", self.a  ," ", "b=",self.b  ," ","c=",self.c)
        print("pass one completed\n")

obj= Tower()
obj.tower(3)
obj.tower(2)
obj.tower(1)
obj.pass1()
obj.pass2()
obj.pass3()
obj.pass4()
obj.pass5()
obj.pass6()
obj.pass7()
# Out:
# tower of hanoi game
#
# given problem a=[3,2,1], b[], c[]
#
# expected output a=[] b[] c[3,2,1]
# a= [3]
# items in tower a
#
# a= [3, 2]
# items in tower a
#
# a= [3, 2, 1]
# items in tower a
#
# a= [3, 2]   b= []   c= [1]
# pass one completed
#
# a= [3]   b= [2]   c= [1]
# pass one completed
#
# a= [3]   b= [2, 1]   c= []
# pass one completed
#
# a= []   b= [2, 1]   c= [3]
# pass one completed
#
# a= [1]   b= [2]   c= [3]
# pass one completed
#
# a= [1]   b= []   c= [3, 2]
# pass one completed
#
# a= []   b= []   c= [3, 2, 1]
# pass one completed
